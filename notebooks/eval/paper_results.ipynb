# %%
import pandas as pd
import matplotlib.pyplot as plt
from multi_annotator.utils import read_results
import multi_annotator.plot as plot
from multi_annotator.plot import (
    do_paper_plot_points,
    get_plot_df_rq2,
    get_plot_df_rq3,
    get_plot_df_rq3_1,
    do_paper_plot_rq3,
    get_plot_df_rq4
)

# %%
df_ = pd.concat([

    # Classification
    read_results(
        '../../experiments/classification/llama3_classification-notokens-dices-instance-lr3e5.results.csv',
        'Llama3 (Classification), Content Only, Instance, DICES-350'
    ),
    read_results(
        '../../experiments/classification/llama3_classification-notokens-intimacy-instance-lr6e5.results.csv',
        'Llama3 (Classification), Content Only, Instance, Intimacy'
    ),
    read_results(
        '../../experiments/mistral-test/mistral-notokens-intimacy-instance-lr6e5.results.csv',
        'Mistral (Classification), Content Only, Instance, Intimacy'
    ),
    read_results(
        '../../experiments/classification/llama3_classification-notokens-offensiveness-instance-lr3e5.results.csv',
        'Llama3 (Classification), Content Only, Instance, Offensiveness'
    ),
    read_results(
        '../../experiments/mistral-test/mistral-notokens-offensiveness-instance-lr3e5.results.csv',
        'Mistral (Classification), Content Only, Instance, Offensiveness'
    ),
    read_results(
        '../../experiments/classification/llama3_classification-notokens-politeness-instance-lr8e5.results.csv',
        'Llama3 (Classification), Content Only, Instance, Politeness'
    ),
    read_results(
        '../../experiments/classification/llama3_classification-notokens-diaz-instance-lr3e5.results.csv',
        'Llama3 (Classification), Content Only, Instance, Sentiment'
    ),

    ## Text
    read_results(
        '../../experiments/classification/llama3_classification-textual-dices-instance-lr6e5.results.csv',
        'Llama3 (Classification), Textual, Instance, DICES-350'
    ),
    read_results(
        '../../experiments/classification/llama3_classification-textual-intimacy-instance-lr6e5.results.csv',
        'Llama3 (Classification), Textual, Instance, Intimacy'
    ),
    read_results(
        '../../experiments/mistral-test/mistral-textual-intimacy-instance-lr6e5.results.csv',
        'Mistral (Classification), Textual, Instance, Intimacy'
    ),
    read_results(
        '../../experiments/classification/llama3_classification-textual-offensiveness-instance-lr8e5.results.csv',
        'Llama3 (Classification), Textual, Instance, Offensiveness'
    ),
    read_results(
        '../../experiments/mistral-test/mistral-textual-offensiveness-instance-lr8e5.results.csv',
        'Mistral (Classification), Textual, Instance, Offensiveness'
    ),
    read_results(
        '../../experiments/classification/llama3_classification-textual-politeness-instance-lr8e5.results.csv',
        'Llama3 (Classification), Textual, Instance, Politeness'
    ),
    read_results(
        '../../experiments/classification/llama3_classification-textual-diaz-instance-lr6e5.results.csv',
        'Llama3 (Classification), Textual, Instance, Sentiment'
    ),

     ## Textual ID
    read_results(
        '../../experiments/annotator-id-test/llama3_classification-textual_id-dices-instance-lr6e5.results.csv',
        'Llama3 (Classification), ID, Instance, DICES-350'
    ),
    read_results(
        '../../experiments/annotator-id-test/llama3_classification-textual_id-intimacy-instance-lr6e5.results.csv',
        'Llama3 (Classification), ID, Instance, Intimacy'
    ),
    read_results(
        '../../experiments/mistral-test/mistral-textual_id-intimacy-instance-lr6e5.results.csv',
        'Mistral (Classification), ID, Instance, Intimacy'
    ),
    read_results(
        '../../experiments/annotator-id-test/llama3_classification-textual_id-offensiveness-instance-lr8e5.results.csv',
        'Llama3 (Classification), ID, Instance, Offensiveness'
    ),
    read_results(
        '../../experiments/mistral-test/mistral-textual_id-offensiveness-instance-lr8e5.results.csv',
        'Mistral (Classification), ID, Instance, Offensiveness'
    ),
    read_results(
        '../../experiments/annotator-id-test/llama3_classification-textual_id-politeness-instance-lr8e5.results.csv',
        'Llama3 (Classification), ID, Instance, Politeness'
    ),
    read_results(
        '../../experiments/annotator-id-test/llama3_classification-textual_id-diaz-instance-lr6e5.results.csv',
        'Llama3 (Classification), ID, Instance, Sentiment'
    ),

    ## Textual Attributes + Textual ID
    read_results(
        '../../experiments/annotator-id-attributes-test/llama3_classification-id+textual-dices-instance-lr6e5.results.csv',
        'Llama3 (Classification), ID+Attributes, Instance, DICES-350'
    ),
    read_results(
        '../../experiments/annotator-id-attributes-test/llama3_classification-id+textual-intimacy-instance-lr8e5.results.csv',
        'Llama3 (Classification), ID+Attributes, Instance, Intimacy'
    ),
    read_results(
        '../../experiments/mistral-test/mistral-id+textual-intimacy-instance-lr8e5.results.csv',
        'Mistral (Classification), ID+Attributes, Instance, Intimacy'
    ),
    read_results(
        '../../experiments/annotator-id-attributes-test/llama3_classification-id+textual-offensiveness-instance-lr8e5.results.csv',
        'Llama3 (Classification), ID+Attributes, Instance, Offensiveness'
    ),
    read_results(
        '../../experiments/mistral-test/mistral-id+textual-offensiveness-instance-lr8e5.results.csv',
        'Mistral (Classification), ID+Attributes, Instance, Offensiveness'
    ),
    read_results(
        '../../experiments/annotator-id-attributes-test/llama3_classification-id+textual-politeness-instance-lr6e5.results.csv',
        'Llama3 (Classification), ID+Attributes, Instance, Politeness'
    ),
    read_results(
        '../../experiments/annotator-id-attributes-test/llama3_classification-id+textual-diaz-instance-lr3e5.results.csv',
        'Llama3 (Classification), ID+Attributes, Instance, Sentiment'
    ),

    ### User - Classification
    ## Content Only
    read_results(
        '../../experiments/classification/llama3_classification-notokens-dices-user-lr3e5.results.csv',
        'Llama3 (Classification), Content Only, User, DICES-350'
    ),
    read_results(
        '../../experiments/classification/llama3_classification-notokens-intimacy-user-lr8e5.results.csv',
        'Llama3 (Classification), Content Only, User, Intimacy'
    ),
    read_results(
        '../../experiments/classification/llama3_classification-notokens-offensiveness-user-lr8e5.results.csv',
        'Llama3 (Classification), Content Only, User, Offensiveness'
    ),
    read_results(
        '../../experiments/classification/llama3_classification-notokens-politeness-user-lr3e5.results.csv',
        'Llama3 (Classification), Content Only, User, Politeness'
    ),
    read_results(
        '../../experiments/classification/llama3_classification-notokens-diaz-user-lr3e5.results.csv',
        'Llama3 (Classification), Content Only, User, Sentiment'
    ),

    ## Text
    read_results(
        '../../experiments/classification/llama3_classification-textual-dices-user-lr3e5.results.csv',
        'Llama3 (Classification), Textual, User, DICES-350'
    ),
    read_results(
        '../../experiments/classification/llama3_classification-textual-intimacy-user-lr8e5.results.csv',
        'Llama3 (Classification), Textual, User, Intimacy'
    ),
    read_results(
        '../../experiments/classification/llama3_classification-textual-offensiveness-user-lr8e5.results.csv',
        'Llama3 (Classification), Textual, User, Offensiveness'
    ),
    read_results(
        '../../experiments/classification/llama3_classification-textual-politeness-user-lr3e5.results.csv',
        'Llama3 (Classification), Textual, User, Politeness'
    ),
    read_results(
        '../../experiments/classification/llama3_classification-textual-diaz-user-lr3e5.results.csv',
        'Llama3 (Classification), Textual, User, Sentiment'
    ),

    ## Textual ID
    read_results(
        '../../experiments/annotator-id-test/llama3_classification-textual_id-dices-user-lr6e5.results.csv',
        'Llama3 (Classification), ID, User, DICES-350'
    ),
    read_results(
        '../../experiments/annotator-id-test/llama3_classification-textual_id-intimacy-user-lr8e5.results.csv',
        'Llama3 (Classification), ID, User, Intimacy'
    ),
    read_results(
        '../../experiments/annotator-id-test/llama3_classification-textual_id-offensiveness-user-lr8e5.results.csv',
        'Llama3 (Classification), ID, User, Offensiveness'
    ),
    read_results(
        '../../experiments/annotator-id-test/llama3_classification-textual_id-politeness-user-lr8e5.results.csv',
        'Llama3 (Classification), ID, User, Politeness'
    ),
    read_results(
        '../../experiments/annotator-id-test/llama3_classification-textual_id-diaz-user-lr3e5.results.csv',
        'Llama3 (Classification), ID, User, Sentiment'
    ),

    ## Textual Attributes + Textual ID
    read_results(
        '../../experiments/annotator-id-attributes-test/llama3_classification-id+textual-dices-user-lr3e5.results.csv',
        'Llama3 (Classification), ID+Attributes, User, DICES-350'
    ),
    read_results(
        '../../experiments/annotator-id-attributes-test/llama3_classification-id+textual-intimacy-user-lr8e5.results.csv',
        'Llama3 (Classification), ID+Attributes, User, Intimacy'
    ),
    read_results(
        '../../experiments/annotator-id-attributes-test/llama3_classification-id+textual-offensiveness-user-lr8e5.results.csv',
        'Llama3 (Classification), ID+Attributes, User, Offensiveness'
    ),
    read_results(
        '../../experiments/annotator-id-attributes-test/llama3_classification-id+textual-politeness-user-lr3e5.results.csv',
        'Llama3 (Classification), ID+Attributes, User, Politeness'
    ),
    read_results(
        '../../experiments/annotator-id-attributes-test/llama3_classification-id+textual-diaz-user-lr3e5.results.csv',
        'Llama3 (Classification), ID+Attributes, User, Sentiment'
    ),

    # Chat Prompting
    ### Instance
    read_results(
        '../../experiments/prompting-rqs-instruct/llama3_instruct-notokens-prompt-intimacy-instance.results.csv',
        'Llama3-Instruct (Chat), Content Only, Instance, Intimacy'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct/llama3_instruct-textual-prompt-intimacy-instance.results.csv',
        'Llama3-Instruct (Chat), Textual, Instance, Intimacy'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct/llama3_instruct-notokens-prompt-dices-instance.results.csv',
        'Llama3-Instruct (Chat), Content Only, Instance, DICES-350'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct/llama3_instruct-textual-prompt-dices-instance.results.csv',
        'Llama3-Instruct (Chat), Textual, Instance, DICES-350'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct/llama3_instruct-notokens-prompt-offensiveness-instance.results.csv',
        'Llama3-Instruct (Chat), Content Only, Instance, Offensiveness'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct/llama3_instruct-textual-prompt-offensiveness-instance.results.csv',
        'Llama3-Instruct (Chat), Textual, Instance, Offensiveness'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct/llama3_instruct-notokens-prompt-politeness-instance.results.csv',
        'Llama3-Instruct (Chat), Content Only, Instance, Politeness'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct/llama3_instruct-textual-prompt-politeness-instance.results.csv',
        'Llama3-Instruct (Chat), Textual, Instance, Politeness'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct/llama3_instruct-notokens-prompt-diaz-instance.results.csv',
        'Llama3-Instruct (Chat), Content Only, Instance, Sentiment'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct/llama3_instruct-textual-prompt-diaz-instance.results.csv',
        'Llama3-Instruct (Chat), Textual, Instance, Sentiment'
    ),

    #### 70B Instruct
    read_results(
        '../../experiments/prompting-rqs-instruct-70b/llama3_instruct_70b-notokens-prompt-intimacy-instance.results.csv',
        'Llama3-Instruct-70B (Chat), Content Only, Instance, Intimacy'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct-70b/llama3_instruct_70b-notokens-prompt-dices-instance.results.csv',
        'Llama3-Instruct-70B (Chat), Content Only, Instance, DICES-350'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct-70b/llama3_instruct_70b-notokens-prompt-politeness-instance.results.csv',
        'Llama3-Instruct-70B (Chat), Content Only, Instance, Politeness'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct-70b/llama3_instruct_70b-notokens-prompt-offensiveness-instance.results.csv',
        'Llama3-Instruct-70B (Chat), Content Only, Instance, Offensivenss'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct-70b/llama3_instruct_70b-notokens-prompt-diaz-instance.results.csv',
        'Llama3-Instruct-70B (Chat), Content Only, Instance, Sentiment'
    ),


    #### long attribute format
    read_results(
        '../../experiments/long-prompting-rqs/llama3_instruct_long-textual-prompt-intimacy-instance.results.csv',
        'Llama3-Instruct (Chat), Textual (Long), Instance, Intimacy'
    ),
    read_results(
        '../../experiments/long-prompting-rqs/llama3_instruct_long-textual-prompt-dices-instance.results.csv',
        'Llama3-Instruct (Chat), Textual (Long), Instance, DICES-350'
    ),
    read_results(
        '../../experiments/long-prompting-rqs/llama3_instruct_long-textual-prompt-offensiveness-instance.results.csv',
        'Llama3-Instruct (Chat), Textual (Long), Instance, Offensiveness'
    ),
    read_results(
        '../../experiments/long-prompting-rqs/llama3_instruct_long-textual-prompt-politeness-instance.results.csv',
        'Llama3-Instruct (Chat), Textual (Long), Instance, Politeness'
    ),
    read_results(
        '../../experiments/long-prompting-rqs/llama3_instruct_long-textual-prompt-diaz-instance.results.csv',
        'Llama3-Instruct (Chat), Textual (Long), Instance, Sentiment'
    ),

    #### 70B Instruct - Instance - long attribute format
    read_results(
        '../../experiments/long-prompting-rqs/llama3_instruct_70b_long-textual-prompt-intimacy-instance.results.csv',
        'Llama3-Instruct-70B (Chat), Textual (Long), Instance, Intimacy'
    ),
    read_results(
        '../../experiments/long-prompting-rqs/llama3_instruct_70b_long-textual-prompt-dices-instance.results.csv',
        'Llama3-Instruct-70B (Chat), Textual (Long), Instance, DICES-350'
    ),  
    read_results(
        '../../experiments/long-prompting-rqs/llama3_instruct_70b_long-textual-prompt-politeness-instance.results.csv',
        'Llama3-Instruct-70B (Chat), Textual (Long), Instance, Politeness'
    ),  
    read_results(
        '../../experiments/long-prompting-rqs/llama3_instruct_70b_long-textual-prompt-offensiveness-instance.results.csv',
        'Llama3-Instruct-70B (Chat), Textual (Long), Instance, Offensiveness'
    ),
    read_results(
        '../../experiments/long-prompting-rqs/llama3_instruct_70b_long-textual-prompt-diaz-instance.results.csv',
        'Llama3-Instruct-70B (Chat), Textual (Long), Instance, Sentiment'
    ),

    ### User - Chat Prompting 
    read_results(
        '../../experiments/prompting-rqs-instruct/llama3_instruct-notokens-prompt-intimacy-user.results.csv',
        'Llama3-Instruct (Chat), Content Only, User, Intimacy'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct/llama3_instruct-textual-prompt-intimacy-user.results.csv',
        'Llama3-Instruct (Chat), Textual, User, Intimacy'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct/llama3_instruct-notokens-prompt-dices-user.results.csv',
        'Llama3-Instruct (Chat), Content Only, User, DICES-350'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct/llama3_instruct-textual-prompt-dices-user.results.csv',
        'Llama3-Instruct (Chat), Textual, User, DICES-350'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct/llama3_instruct-notokens-prompt-offensiveness-user.results.csv',
        'Llama3-Instruct (Chat), Content Only, User, Offensiveness'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct/llama3_instruct-textual-prompt-offensiveness-user.results.csv',
        'Llama3-Instruct (Chat), Textual, User, Offensiveness'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct/llama3_instruct-notokens-prompt-politeness-user.results.csv',
        'Llama3-Instruct (Chat), Content Only, User, Politeness'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct/llama3_instruct-textual-prompt-politeness-user.results.csv',
        'Llama3-Instruct (Chat), Textual, User, Politeness'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct/llama3_instruct-notokens-prompt-diaz-user.results.csv',
        'Llama3-Instruct (Chat), Content Only, User, Sentiment'
    ),
    read_results(
        '../../experiments/prompting-rqs-instruct/llama3_instruct-textual-prompt-diaz-instance.results.csv',
        'Llama3-Instruct (Chat), Textual, User, Sentiment'
    ),

    #### long attribute format
    read_results(
        '../../experiments/long-prompting-rqs/llama3_instruct_long-textual-prompt-intimacy-user.results.csv',
        'Llama3-Instruct (Chat), Textual (Long), User, Intimacy'
    ),
    read_results(
        '../../experiments/long-prompting-rqs/llama3_instruct_long-textual-prompt-dices-user.results.csv',
        'Llama3-Instruct (Chat), Textual (Long), User, DICES-350'
    ),
    read_results(
        '../../experiments/long-prompting-rqs/llama3_instruct_long-textual-prompt-offensiveness-user.results.csv',
        'Llama3-Instruct (Chat), Textual (Long), User, Offensiveness'
    ),
    read_results(
        '../../experiments/long-prompting-rqs/llama3_instruct_long-textual-prompt-politeness-user.results.csv',
        'Llama3-Instruct (Chat), Textual (Long), User, Politeness'
    ),
    read_results(
        '../../experiments/long-prompting-rqs/llama3_instruct_long-textual-prompt-diaz-user.results.csv',
        'Llama3-Instruct (Chat), Textual (Long), User, Sentiment'
    )
]).reset_index()

# %%
df_['tasks'].unique()
# Out:
# array(['dices-350', 'intimacy', 'offensiveness', 'politeness', 'diaz'],
#       dtype=object)

# %%
df_['init'] = df_['init'].apply(lambda x: x.split('-')[-1])

# %%
df_['num_tokens'] = df_['num_tokens'].apply(lambda x: x.split('-')[-1])

# %%
df_['use_description'] = df_['use_description'].apply(lambda x: x.split('-')[-1])

# %%
def get_split(config):
    config = config.lower()
    if 'instance' in config:
        return 'instance'
    elif 'user' in config:
        return 'annotator'
    else:
        raise NotImplementedError()

df_['split'] = df_['config'].apply(get_split)

# %%
df = df_

# %% [markdown]
# ## RQ2 (No RQ in Paper, Baseline in Appendix)
#
# Does prompting with sociodemographic attributes improve predictions of subjective text perceptions?

# %%
performance = get_plot_df_rq2(df).groupby(['tasks', 'config'])['f1'].describe()
performance
# Out:
#                                   count      mean       std       min  \
# tasks         config
# Intimacy      +Attributes          30.0  0.218497  0.006054  0.207122
#               +Attributes (70B)    30.0  0.259746  0.005335  0.248020
#               Attributes List      30.0  0.201020  0.005578  0.188208
#               Content Only         30.0  0.219090  0.007503  0.202866
#               Content Only (70B)   30.0  0.248777  0.005231  0.237270
# Offensiveness +Attributes          30.0  0.260303  0.004805  0.249595
#               +Attributes (70B)    30.0  0.297005  0.004071  0.288196
#               Attributes List      30.0  0.233891  0.005444  0.222451
#               Content Only         30.0  0.260826  0.006005  0.248516
#               Content Only (70B)   30.0  0.320613  0.004100  0.313559
# Politeness    +Attributes          30.0  0.317527  0.003313  0.308182
#               +Attributes (70B)    30.0  0.340674  0.002986  0.333971
# ...

# %%
max_f1s = performance.groupby('tasks')['50%'].max()

# %%
best_zero_shot_incl70B = performance[performance.apply(lambda row: row['50%'] == max_f1s[row.name[0]], axis=1)]
best_zero_shot_incl70B
# Out:
#                                   count      mean       std       min  \
# tasks         config
# Intimacy      +Attributes (70B)    30.0  0.259746  0.005335  0.248020
# Offensiveness Content Only (70B)   30.0  0.320613  0.004100  0.313559
# Politeness    +Attributes (70B)    30.0  0.340674  0.002986  0.333971
# Safety        Content Only (70B)   30.0  0.315778  0.002185  0.311143
# Sentiment     +Attributes (70B)    30.0  0.316920  0.000815  0.315384
#
#                                        25%       50%       75%       max
# tasks         config
# Intimacy      +Attributes (70B)   0.255685  0.260244  0.263872  0.272081
# Offensiveness Content Only (70B)  0.317469  0.320933  0.323693  0.329179
# Politeness    +Attributes (70B)   0.338938  0.340475  0.342470  0.345677
# Safety        Content Only (70B)  0.314372  0.315818  0.317238  0.321086
# Sentiment     +Attributes (70B)   0.316398  0.316781  0.317601  0.318473

# %%
get_plot_df_rq2(df).groupby(['tasks','config'])['f1'].describe()
# Out:
#                                   count      mean       std       min  \
# tasks         config
# Intimacy      +Attributes          30.0  0.218497  0.006054  0.207122
#               +Attributes (70B)    30.0  0.259746  0.005335  0.248020
#               Attributes List      30.0  0.201020  0.005578  0.188208
#               Content Only         30.0  0.219090  0.007503  0.202866
#               Content Only (70B)   30.0  0.248777  0.005231  0.237270
# Offensiveness +Attributes          30.0  0.260303  0.004805  0.249595
#               +Attributes (70B)    30.0  0.297005  0.004071  0.288196
#               Attributes List      30.0  0.233891  0.005444  0.222451
#               Content Only         30.0  0.260826  0.006005  0.248516
#               Content Only (70B)   30.0  0.320613  0.004100  0.313559
# Politeness    +Attributes          30.0  0.317527  0.003313  0.308182
#               +Attributes (70B)    30.0  0.340674  0.002986  0.333971
# ...

# %%
# user
from multi_annotator.plot import map_config_name_rq2
zeroshot_users = df[df['config'].apply(lambda c: 'user' in c.lower() and not 'non-chat' in c.lower() and 'instruct' in c.lower())]
zeroshot_users = zeroshot_users.reset_index(drop=True).apply(map_config_name_rq2, axis=1)
zeroshot_users.groupby(['tasks', 'config'])['f1'].describe()
# Out:
#                                count      mean       std       min       25%  \
# tasks         config
# diaz          +Attributes       30.0  0.282182  0.001774  0.278667  0.280892
#               Attributes List   30.0  0.270034  0.001676  0.267123  0.268784
#               Content Only      30.0  0.287230  0.001520  0.283821  0.286380
# dices-350     +Attributes       30.0  0.258866  0.002725  0.254529  0.256924
#               Attributes List   30.0  0.242199  0.002610  0.237692  0.240059
#               Content Only      30.0  0.252183  0.002875  0.246658  0.250772
# intimacy      +Attributes       30.0  0.199516  0.007413  0.188546  0.193317
#               Attributes List   30.0  0.182912  0.007693  0.163797  0.177487
#               Content Only      30.0  0.206141  0.005175  0.196740  0.202401
# offensiveness +Attributes       30.0  0.249441  0.004613  0.238687  0.246141
#               Attributes List   30.0  0.226711  0.004121  0.220989  0.223941
# ...

# %%
# best user zero-shot
f1s_users = zeroshot_users.groupby(['tasks', 'config'])['f1'].describe()
max_means = f1s_users.groupby(['tasks']).max()
f1s_users[f1s_users['mean'].isin(max_means['mean'])]
# Out:
#                             count      mean       std       min       25%  \
# tasks         config
# diaz          Content Only   30.0  0.287230  0.001520  0.283821  0.286380
# dices-350     +Attributes    30.0  0.258866  0.002725  0.254529  0.256924
# intimacy      Content Only   30.0  0.206141  0.005175  0.196740  0.202401
# offensiveness Content Only   30.0  0.254100  0.005000  0.242894  0.251359
# politeness    +Attributes    30.0  0.293788  0.003551  0.286614  0.292409
#
#                                  50%       75%       max
# tasks         config
# diaz          Content Only  0.287444  0.288501  0.289685
# dices-350     +Attributes   0.259134  0.260916  0.265153
# intimacy      Content Only  0.206160  0.209253  0.220672
# offensiveness Content Only  0.253908  0.258008  0.262398
# politeness    +Attributes   0.294017  0.296065  0.300601

# %%
do_paper_plot_points(df, rq=2)

# %%
with plt.style.context("./fig/acl-column.mplstyle"):
    ax = do_paper_plot_points(df, rq=2, is_paper=True)
    plt.savefig(
        'fig/rq2-col.pgf',
        dpi=300
    )
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'serif' not found because none of the following families were found: Times

# %% [markdown]
# ## RQ3 (RQ1 in Paper)
#
# Can we learn how to better learn how individuals would rate unseen texts given their attributes?

# %%
df_rq3 = get_plot_df_rq3(df)[['tasks', 'seed', 'split', 'config', 'f1']]

# %%
scores_rq3 = df_rq3.groupby(['tasks', 'config'])['f1'].describe()
scores_rq3
# Out:
#                                      count      mean       std       min  \
# tasks         config
# Intimacy      +Attributes (FTed)      30.0  0.303079  0.015493  0.274361
#               +ID (FTed)              30.0  0.444603  0.009829  0.428356
#               +ID+Attributes (FTed)   30.0  0.448722  0.009232  0.427585
#               Best Zero-Shot          30.0  0.219090  0.007503  0.202866
#               Content Only (FTed)     30.0  0.266030  0.014546  0.233568
# Offensiveness +Attributes (FTed)      30.0  0.277492  0.008498  0.259573
#               +ID (FTed)              30.0  0.377110  0.014525  0.348157
#               +ID+Attributes (FTed)   30.0  0.383494  0.019363  0.294978
#               Best Zero-Shot          30.0  0.260826  0.006005  0.248516
#               Content Only (FTed)     30.0  0.232949  0.013832  0.209341
# Politeness    +Attributes (FTed)      30.0  0.398065  0.004884  0.388260
# ...

# %%
df_rq3.to_csv('../../data/plot/rq3.csv', index=False)

# %%
with plt.style.context("./fig/acl-column.mplstyle"):
    ax = do_paper_plot_rq3(metric='f1', horizontal=False)
    plt.savefig(
        'fig/rq3-col.pgf',
        dpi=300
    )
    plt.savefig(
        'fig/rq3-col.png',
        dpi=300
    )
    plt.close()

# %%
with plt.style.context("./fig/acl.mplstyle"):
    ax = do_paper_plot_rq3(metric='f1', horizontal=False)
    plt.savefig(
        'fig/rq3.pgf',
        dpi=300
    )
    plt.close()

# %% [markdown]
# ### Find run that is closest to mean score

# %%
df_rq3['mean_f1_distance'] = df_rq3.apply(lambda row: abs(row['f1'] - scores_rq3.loc[(row['tasks'], row['config'])]['mean']), axis=1)

# %%
closest_to_mean_runs_rq3 = df_rq3.iloc[df_rq3.groupby(['tasks', 'config'])['mean_f1_distance'].idxmin()]

# %%
closest_to_mean_runs_rq3[['tasks', 'config','seed']].groupby(['tasks', 'config']).first().to_dict()
# Out:
# {'seed': {('Intimacy', '+Attributes (Llama 3 FTed)'): 701702170,
#   ('Intimacy', '+Attributes (Mistral FTed)'): 701702170,
#   ('Intimacy', '+ID (Llama 3 FTed)'): 370276791,
#   ('Intimacy', '+ID (Mistral FTed)'): 621609371,
#   ('Intimacy', '+ID+Attributes (Llama 3 FTed)'): 124600042,
#   ('Intimacy', '+ID+Attributes (Mistral FTed)'): 536804,
#   ('Intimacy', 'Best Zero-Shot'): 1885444771,
#   ('Intimacy', 'Content Only (Llama 3 FTed)'): 185007946,
#   ('Intimacy', 'Content Only (Mistral FTed)'): 3208936010,
#   ('Offensiveness', '+Attributes (Llama 3 FTed)'): 370276791,
#   ('Offensiveness', '+ID (Llama 3 FTed)'): 1885444771,
#   ('Offensiveness', '+ID+Attributes (Llama 3 FTed)'): 277728153,
#   ('Offensiveness', 'Best Zero-Shot'): 224600032,
#   ('Offensiveness', 'Content Only (Llama 3 FTed)'): 277728153,
#   ('Politeness', '+Attributes (Llama 3 FTed)'): 277728153,
#   ('Politeness', '+ID (Llama 3 FTed)'): 799443590,
# ...

# %% [markdown]
# intimacy: 0.260244, offesniveness: 0.320933, politeness: 0.340475, safety: 0.315818, sentiment: 0.319416

# %% [markdown]
# ### RQ3.1 Additional Model Families (No RQ in Paper, Supplementary Experiment in Appendix)

# %%
df_rq31 = get_plot_df_rq3_1(df)

# %%
df_rq31.groupby(['model', 'attributes'])['f1'].describe()
# Out:
#                                                                count  \
# model                   attributes
# Llama3 - Intimacy       none                                    10.0
#                         race, gender, age, education            10.0
#                         user_id                                 10.0
#                         user_id, race, gender, age, education   10.0
# Llama3 - Offensiveness  none                                    10.0
#                         race, gender, age, education            10.0
#                         user_id                                 10.0
#                         user_id, race, gender, age, education   10.0
# Mistral - Intimacy      none                                    10.0
#                         race, gender, age, education            10.0
#                         user_id                                  9.0
#                         user_id, race, gender, age, education   10.0
# ...

# %%
plot.do_paper_plot_points(df, rq=3.1)

# %%
with plt.style.context("./fig/acl-column.mplstyle"):
    ax = plot.do_paper_plot_points(df, rq=3.1, is_paper=True)
    plt.savefig(
        'fig/rq31-col.pgf',
        dpi=300
    )
    plt.savefig(
        'fig/rq31-col.png',
        dpi=300
    )
    plt.close()
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'serif' not found because none of the following families were found: Times

# %%
do_paper_plot_points(df, rq=3)

# %%
with plt.style.context("./fig/acl-column.mplstyle"):
    ax = do_paper_plot_points(df, rq=3, is_paper=True)
    plt.savefig(
        'fig/rq3-col.pgf',
        dpi=300
    )

# %% [markdown]
# ## RQ4 (RQ2 in Paper)
# Can we learn to predict how unseen annotators rate text?

# %%
do_paper_plot_points(df, rq=4)

# %%
with plt.style.context("./fig/acl-column.mplstyle"):
    ax = do_paper_plot_points(df, rq=4, is_paper=True)
    plt.savefig(
        'fig/rq4-col.pgf',
        dpi=300
    )
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# findfont: Generic family 'serif' not found because none of the following families were found: Times

# %%
# zero-shot results for annotator split
df[(df['split'] == 'annotator')& (df['config'].apply(lambda c: 'chat' in c.lower()))].groupby(['tasks', 'config'])['f1'].describe()
# Out:
#                                                                   count  \
# tasks         config
# diaz          Llama3-Instruct (Chat), Content Only, User, Sen...   30.0
#               Llama3-Instruct (Chat), Textual (Long), User, S...   30.0
#               Llama3-Instruct (Chat), Textual, User, Sentiment     30.0
# dices-350     Llama3-Instruct (Chat), Content Only, User, DIC...   30.0
#               Llama3-Instruct (Chat), Textual (Long), User, D...   30.0
#               Llama3-Instruct (Chat), Textual, User, DICES-350     30.0
# intimacy      Llama3-Instruct (Chat), Content Only, User, Int...   30.0
#               Llama3-Instruct (Chat), Textual (Long), User, I...   30.0
#               Llama3-Instruct (Chat), Textual, User, Intimacy      30.0
# offensiveness Llama3-Instruct (Chat), Content Only, User, Off...   30.0
#               Llama3-Instruct (Chat), Textual (Long), User, O...   30.0
#               Llama3-Instruct (Chat), Textual, User, Offensiv...   30.0
# ...

# %%
get_plot_df_rq4(df).groupby(['tasks', 'config'])['f1'].describe()
# Out:
#                                      count      mean       std       min  \
# tasks         config
# Intimacy      +Attributes (FTed)      30.0  0.272827  0.007960  0.254906
#               +ID (FTed)              30.0  0.283288  0.008717  0.267913
#               +ID+Attributes (FTed)   30.0  0.281482  0.008572  0.261158
#               Best Zero-Shot          30.0  0.206141  0.005175  0.196740
#               Content Only (FTed)     30.0  0.262641  0.008490  0.249060
# Offensiveness +Attributes (FTed)      30.0  0.295637  0.007280  0.285998
#               +ID (FTed)              30.0  0.303541  0.007407  0.289977
#               +ID+Attributes (FTed)   30.0  0.302414  0.021969  0.192600
#               Best Zero-Shot          30.0  0.254100  0.005000  0.242894
#               Content Only (FTed)     30.0  0.281887  0.009079  0.264392
# Politeness    +Attributes (FTed)      30.0  0.376277  0.005992  0.365045
# ...

# %%
df_rq4 = get_plot_df_rq4(df)[['tasks', 'seed', 'split', 'config', 'f1']]

# %%
df_rq4.to_csv('../../data/plot/rq4.csv', index=False)
